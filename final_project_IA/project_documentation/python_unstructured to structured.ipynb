# %%
123

# %%
import pandas as pd

with open('vehicle.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

df.to_csv('Motor_Vehicle_Crashes_-_Violation_Information__Three_Year_Window.csv', encoding='utf-8', index=False)

# %%
df
# Out:
#         Year                              Violation Description  \
# 0       2019                         UNREGISTERED MOTOR VEHICLE
# 1       2019                                UNLICENSED OPERATOR
# 2       2019                          DRIVING WHILE INTOXICATED
# 3       2019                        REFUSAL TO TAKE BREATH TEST
# 4       2019  AGGRAVATED DWI - BLOOD ALCOHOL CONTENT .18 OR ...
# ...      ...                                                ...
# 238039  2018                       OPERATING W/O INSURANCE INF.
# 238040  2018                          DRIVING WHILE INTOXICATED
# 238041  2018                        DROVE ACROSS HAZARD MARKING
# 238042  2018                          DRIVING WHILE INTOXICATED
# 238043  2018  AGGRAVATED DWI - BLOOD ALCOHOL CONTENT .18 OR ...
#
#        Violation Code  Case Individual ID
# 0               4011A            21443237
# 1                5091            21443393
# 2               11923            21443718
# ...
